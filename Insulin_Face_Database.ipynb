# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#copy the path to your file
face_df = pd.read_csv('/content/drive/MyDrive/FaceDataClean.csv')

# %%
face_df.head()
# Out:
#     Model EthnicitySelf GenderSelf  AgeSelf   AgeRated  Unnamed: 5  \
# 0  AF-200             A          F      NaN  32.571429         NaN
# 1  AF-201             A          F      NaN  23.666667         NaN
# 2  AF-202             A          F      NaN  24.448276         NaN
# 3  AF-203             A          F      NaN  22.758621         NaN
# 4  AF-204             A          F      NaN  30.137931         NaN
#
#    FemaleProb  MaleProb  AsianProb  ChineseAsianProb  ...   EyeSize  \
# 0    1.000000  0.000000   1.000000               NaN  ...  0.060924
# 1    1.000000  0.000000   0.962963               NaN  ...  0.041892
# 2    0.827586  0.172414   0.310345               NaN  ...  0.051586
# 3    1.000000  0.000000   0.758621               NaN  ...  0.063913
# 4    1.000000  0.000000   0.827586               NaN  ...  0.053435
#
#    UpperHeadLength  MidfaceLength  ChinLength  ForeheadHeight  \
# 0         0.414099       0.326797    0.130719        0.264706
# ...

# %%
face_df.columns
# Out:
# Index(['Model', 'EthnicitySelf', 'GenderSelf', 'AgeSelf', 'AgeRated',
#        'Unnamed: 5', 'FemaleProb', 'MaleProb', 'AsianProb', 'ChineseAsianProb',
#        ...
#        'EyeSize', 'UpperHeadLength', 'MidfaceLength', 'ChinLength',
#        'ForeheadHeight', 'CheekboneHeight', 'CheekboneProminence',
#        'FaceRoundness', 'fWHR2', 'RaterN'],
#       dtype='object', length=118)

# %%
face_df["Attractive"]
# Out:
# 0      4.111111
# 1      3.111111
# 2      3.000000
# 3      3.275862
# 4      3.172414
#          ...
# 592    3.153846
# 593    2.259259
# 594    2.269231
# 595    3.740741
# 596    2.148148
# Name: Attractive, Length: 597, dtype: float64

# %%
simple_face_df = face_df[["Model", "EthnicitySelf", "GenderSelf", "Attractive"]]

# %%
simple_face_df.head()
# Out:
#     Model EthnicitySelf GenderSelf  Attractive
# 0  AF-200             A          F    4.111111
# 1  AF-201             A          F    3.111111
# 2  AF-202             A          F    3.000000
# 3  AF-203             A          F    3.275862
# 4  AF-204             A          F    3.172414

# %%
simple_face_df["Attractive"].mean()
# Out:
# 3.231866269919598

# %%
black_df = simple_face_df[simple_face_df["EthnicitySelf"] == "B"]

# %%
black_df.head()
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 109  BF-001             B          F    2.730337
# 110  BF-002             B          F    4.892473
# 111  BF-003             B          F    3.191011
# 112  BF-004             B          F    2.711111
# 113  BF-005             B          F    4.076923

# %%
df_mean = black_df["Attractive"].mean()
df_standard = black_df["Attractive"].std()

# %%
print(df_mean + df_standard)
print(df_mean - df_standard)
# Out:
# 4.034182131495685
# 2.4742716633672592

# %%
av_df = black_df[(black_df["Attractive"] < 4.034) & (black_df["Attractive"] > 2.474)]

# %%
av_df.head()
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 109  BF-001             B          F    2.730337
# 111  BF-003             B          F    3.191011
# 112  BF-004             B          F    2.711111
# 114  BF-006             B          F    3.380435
# 116  BF-008             B          F    3.068966

# %%
female_av_df = av_df[av_df["GenderSelf"] == "F"]

# %%
male_av_df = av_df[av_df["GenderSelf"] == "M"]

# %%
#randomly generate 3 models from female_av_df
female_av_df.sample(n=3)
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 116  BF-008             B          F    3.068966
# 196  BF-239             B          F    3.103448
# 124  BF-016             B          F    2.476190

# %%
male_av_df.sample(n=3)
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 232  BM-024             B          M    2.989474
# 270  BM-217             B          M    2.857143
# 280  BM-228             B          M    4.000000

# %%
#what is the max Attractive value from the black_df
print(black_df["Attractive"].max())
#where does this occur in the dataframe?
black_df[black_df["Attractive"] == 5.310344828]
# Out:
# 5.310344828
#       Model EthnicitySelf GenderSelf  Attractive
# 197  BF-240             B          F    5.310345

# %%
black_df["Attractive"].min()
black_df[black_df["Attractive"] == 1.551724138]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 157  BF-200             B          F    1.551724

# %%
black_men_df = black_df[black_df["GenderSelf"] == "M"]

# %%
black_men_df["Attractive"].max()
black_men_df[black_men_df["Attractive"] == 4.852272727]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 249  BM-043             B          M    4.852273

# %%
black_men_df["Attractive"].min()
black_men_df[black_men_df["Attractive"] == 2.08]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 266  BM-213             B          M        2.08

# %%
madi_models = simple_face_df[simple_face_df["Model"].isin(["BF-008", "BF-239", "BF-016", 'BF-240', 'BF-200', 'BM-024', 'BM-217', 'BM-228', 'BM-043', 'BM-213'])]

# %%
madi_models
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 116  BF-008             B          F    3.068966
# 124  BF-016             B          F    2.476190
# 157  BF-200             B          F    1.551724
# 196  BF-239             B          F    3.103448
# 197  BF-240             B          F    5.310345
# 232  BM-024             B          M    2.989474
# 249  BM-043             B          M    4.852273
# 266  BM-213             B          M    2.080000
# 270  BM-217             B          M    2.857143
# 280  BM-228             B          M    4.000000

# %%
white_df = simple_face_df[simple_face_df["EthnicitySelf"] == "W"]
white_df.head()
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 414  WF-001             W          F    3.105263
# 415  WF-002             W          F    1.612903
# 416  WF-003             W          F    4.890110
# 417  WF-005             W          F    3.033708
# 418  WF-006             W          F    3.478723

# %%
white_mean = white_df["Attractive"].mean()
white_std = white_df["Attractive"].std()
print(white_mean + white_std)
print(white_mean - white_std)
# Out:
# 3.9956917832457037
# 2.4098023390275207

# %%
avg_white_df = white_df[(white_df["Attractive"] < 3.996) & (white_df["Attractive"] > 2.41)]

# %%
female_avwhite_df = avg_white_df[avg_white_df["GenderSelf"] == "F"]
male_avwhite_df = avg_white_df[avg_white_df["GenderSelf"] == "M"]

# %%
female_avwhite_df.sample(n=3)
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 425  WF-013             W          F    3.565217
# 418  WF-006             W          F    3.478723
# 464  WF-213             W          F    3.241379

# %%
male_avwhite_df.sample(n=3)
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 529  WM-031             W          M    3.045977
# 530  WM-032             W          M    2.643678
# 554  WM-214             W          M    3.120000

# %%
all_female_white = white_df[white_df["GenderSelf"] == "F"]
all_male_white = white_df[white_df["GenderSelf"] == "M"]
all_female_white["Attractive"].max()
all_female_white[all_female_white["Attractive"] == 5.47826087]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 484  WF-233             W          F    5.478261

# %%
all_female_white["Attractive"].min()
all_female_white[all_female_white["Attractive"] == 1.612903226]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 415  WF-002             W          F    1.612903

# %%
all_male_white["Attractive"].max()
all_male_white[all_male_white["Attractive"] == 4.663043478]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 507  WM-004             W          M    4.663043

# %%
all_male_white["Attractive"].min()
all_male_white[all_male_white["Attractive"] == 1.727272727]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 541  WM-201             W          M    1.727273

# %%
madi_models_white = simple_face_df[simple_face_df["Model"].isin(['WF-013', 'WF-006', 'WF-213', 'WF-002', 'WF-233', 'WM-031', 'WM-032', 'WM-214', 'WM-004', 'WM-201'])]

# %%
madi_models_white
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 415  WF-002             W          F    1.612903
# 418  WF-006             W          F    3.478723
# 425  WF-013             W          F    3.565217
# 464  WF-213             W          F    3.241379
# 484  WF-233             W          F    5.478261
# 507  WM-004             W          M    4.663043
# 529  WM-031             W          M    3.045977
# 530  WM-032             W          M    2.643678
# 541  WM-201             W          M    1.727273
# 554  WM-214             W          M    3.120000

# %%
asian_df = simple_face_df[simple_face_df["EthnicitySelf"] == "A"]
asian_df.head()
# Out:
#     Model EthnicitySelf GenderSelf  Attractive
# 0  AF-200             A          F    4.111111
# 1  AF-201             A          F    3.111111
# 2  AF-202             A          F    3.000000
# 3  AF-203             A          F    3.275862
# 4  AF-204             A          F    3.172414

# %%
asian_mean = asian_df["Attractive"].mean()
asian_std = asian_df["Attractive"].std()
print(asian_mean + asian_std)
print(asian_mean - asian_std)
# Out:
# 4.03168570519261
# 2.4950400780183997

# %%
asian_average = asian_df[(asian_df["Attractive"] < 4.032) & (asian_df["Attractive"] > 2.495)]

# %%
female_avasian = asian_average[asian_average["GenderSelf"] == "F"]
male_avasian = asian_average[asian_average["GenderSelf"] == "M"]

# %%
female_avasian.sample(n=3)
# Out:
#      Model EthnicitySelf GenderSelf  Attractive
# 27  AF-227             A          F    3.920000
# 8   AF-208             A          F    3.038462
# 2   AF-202             A          F    3.000000

# %%
male_avasian.sample(n=3)
# Out:
#      Model EthnicitySelf GenderSelf  Attractive
# 73  AM-217             A          M    2.538462
# 77  AM-221             A          M    3.230769
# 92  AM-237             A          M    3.269231

# %%
all_femaleasian = asian_df[asian_df["GenderSelf"] == "F"]
all_maleasian = asian_df[asian_df["GenderSelf"] == "M"]

# %%
all_femaleasian["Attractive"].max()
all_femaleasian[all_femaleasian["Attractive"] == 4.964285714]
# Out:
#      Model EthnicitySelf GenderSelf  Attractive
# 42  AF-242             A          F    4.964286

# %%
all_femaleasian["Attractive"].min()
all_femaleasian[all_femaleasian["Attractive"] == 2.137931034]
# Out:
#     Model EthnicitySelf GenderSelf  Attractive
# 7  AF-207             A          F    2.137931

# %%
all_maleasian["Attractive"].max()
all_maleasian[all_maleasian["Attractive"] == 4.12]
# Out:
#      Model EthnicitySelf GenderSelf  Attractive
# 72  AM-216             A          M        4.12

# %%
all_maleasian["Attractive"].min()
all_maleasian[all_maleasian["Attractive"] == 1.52]
# Out:
#      Model EthnicitySelf GenderSelf  Attractive
# 79  AM-224             A          M        1.52

# %%
madi_asian_models = simple_face_df[simple_face_df["Model"].isin(['AF-227', 'AF-208', 'AF-202', 'AF-242', 'AF-207', 'AM-217', 'AM-221','AM-237', 'AM-216', 'AM-224'])]

# %%
madi_asian_models
# Out:
#      Model EthnicitySelf GenderSelf  Attractive
# 2   AF-202             A          F    3.000000
# 7   AF-207             A          F    2.137931
# 8   AF-208             A          F    3.038462
# 27  AF-227             A          F    3.920000
# 42  AF-242             A          F    4.964286
# 72  AM-216             A          M    4.120000
# 73  AM-217             A          M    2.538462
# 77  AM-221             A          M    3.230769
# 79  AM-224             A          M    1.520000
# 92  AM-237             A          M    3.269231

# %%
latino_df = simple_face_df[simple_face_df["EthnicitySelf"] == "L"]

# %%
latino_mean= latino_df["Attractive"].mean()
latino_std = latino_df["Attractive"].std()
print(latino_mean + latino_std)
print(latino_mean - latino_std)
# Out:
# 3.9212433530179123
# 2.4960195539265326

# %%
average_latino = latino_df[(latino_df["Attractive"] < 3.9212) & (latino_df["Attractive"] > 2.496)]

# %%
female_latavg = average_latino[average_latino['GenderSelf']=='F']
male_latavg = average_latino[average_latino['GenderSelf']=='M']

# %%
female_latavg.sample(n=3)
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 360  LF-254             L          F    3.541667
# 324  LF-218             L          F    2.758621
# 313  LF-207             L          F    2.928571

# %%
male_latavg.sample(n=3)
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 382  LM-221             L          M    3.296296
# 368  LM-207             L          M    3.100000
# 398  LM-237             L          M    2.590909

# %%
all_latfemale = latino_df[latino_df["GenderSelf"] == "F"]
all_latmale = latino_df[latino_df["GenderSelf"] == "M"]

# %%
all_latfemale["Attractive"].max()
all_latfemale[all_latfemale["Attractive"] == 5.24137931]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 355  LF-249             L          F    5.241379

# %%
all_latfemale["Attractive"].min()
all_latfemale[all_latfemale["Attractive"] == 2.0]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 326  LF-220             L          F         2.0

# %%
all_latmale["Attractive"].max()
all_latmale[all_latmale["Attractive"] == 5.071428571]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 385  LM-224             L          M    5.071429

# %%
all_latmale["Attractive"].min()
all_latmale[all_latmale["Attractive"] == 1.541666667]
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 401  LM-240             L          M    1.541667

# %%
madi_latino_models = simple_face_df[simple_face_df["Model"].isin(['LF-254', 'LF-218', 'LF-207', 'LF-249', 'LF-220','LM-221', 'LM-207','LM-237','LM-224','LM-240'])]

# %%
madi_latino_models
# Out:
#       Model EthnicitySelf GenderSelf  Attractive
# 313  LF-207             L          F    2.928571
# 324  LF-218             L          F    2.758621
# 326  LF-220             L          F    2.000000
# 355  LF-249             L          F    5.241379
# 360  LF-254             L          F    3.541667
# 368  LM-207             L          M    3.100000
# 382  LM-221             L          M    3.296296
# 385  LM-224             L          M    5.071429
# 398  LM-237             L          M    2.590909
# 401  LM-240             L          M    1.541667
